# %%
import sys; sys.path.append('..')
from crossreads_petrography import *
# Out:
# Loading config from /Users/ryan/github/crossreads-petrography/notebooks/../data/default_config.yaml

# %%
xrd_converter = XRDConverter()
xrd_converter.save()
# Out:
# Postprocessing XRD data
# ESD (0.0018) is larger than value (0.0008) for ISic001482 on qcalcitmg
# ESD (0.0014) is larger than value (0.0011) for ISic001158 on qquartz
# ESD (0.005) is larger than value (0.0047) for ISic000029grey on qenstatitemg06fe04
# ESD (0.0014) is larger than value (0.001) for ISic000689 on qmusc1md
# ESD (11.0) is larger than value (0.0) for ISic000231 on qcalcite
# ESD (1.9) is larger than value (0.1) for ISic000231 on qquartz
# ESD (13.0) is larger than value (0.0) for ISic000231 on qchloritfxbg
# ESD (28.0) is larger than value (1.0) for ISic000509 on qcalcite
# ESD (0.16) is larger than value (0.0) for ISic000509 on qquartz
# ESD (28.0) is larger than value (0.0) for ISic000509 on qchloritfxbg
# Saved: /Users/ryan/github/crossreads-petrography/data/XRD/output/2024-12-13/xrd_data_postprocessed_sums.xlsx
# Saved: /Users/ryan/github/crossreads-petrography/data/XRD/output/2024-12-13/xrd_data_postprocessed_esds.xlsx

# %%
df=xrd_converter.df_output_esds
df
# Out:
# ESD (0.0018) is larger than value (0.0008) for ISic001482 on qcalcitmg
# ESD (0.0014) is larger than value (0.0011) for ISic001158 on qquartz
# ESD (0.005) is larger than value (0.0047) for ISic000029grey on qenstatitemg06fe04
# ESD (0.0014) is larger than value (0.001) for ISic000689 on qmusc1md
# ESD (11.0) is larger than value (0.0) for ISic000231 on qcalcite
# ESD (1.9) is larger than value (0.1) for ISic000231 on qquartz
# ESD (13.0) is larger than value (0.0) for ISic000231 on qchloritfxbg
# ESD (28.0) is larger than value (1.0) for ISic000509 on qcalcite
# ESD (0.16) is larger than value (0.0) for ISic000509 on qquartz
# ESD (28.0) is larger than value (0.0) for ISic000509 on qchloritfxbg
#                 Calcite Quartz Dolomite Clay Minerals Plagioclases  \
# Sample
# ISic000004       96.580
# ISic000009grey  100.000
# ISic000009pink   93.550            2.55          2.21
# ISic000015      100.000
# ISic000017      100.000
# ...

# %%
df.Total.describe()
# Out:
# count    191.000000
# mean      98.613005
# std        6.736199
# min       10.000000
# 25%       99.098000
# 50%      100.000000
# 75%      100.000000
# max      100.059000
# Name: Total, dtype: float64

# %%
xrd_converter.df_mineral_types

# %%
pd.options.display.max_colwidth = None

# %%
xrd_converter.df_input

# %%
df=xrd_converter.df_reformatted
df

# %%
xrd_converter.df_output_sums.sum(axis=1, numeric_only=True).sort_values(ascending=False)

# %%
xrd_converter.df_reformatted

# %%
xrd_converter.df_output

# %%
xrd_converter.df_mineral_types

# %%
xrd_converter.df_output.loc['ISic000097p']

# %%
xrd_converter.run()
