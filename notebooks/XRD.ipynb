# %%
import sys; sys.path.append('..')
from crossreads_petrography import *
# Out:
# Loading config from /Users/ryan/github/crossreads-petrography/notebooks/../data/default_config.yaml

# %%
xrd_converter = XRDConverter()

# %%
xrd_converter.df_input
# Out:
#                                                   File    Sample Sample ID  \
# 0    E:/nextcloud/ISicily/petrography/XRD/001207vg.lst  001207vg
# 1    E:/nextcloud/ISicily/petrography/XRD/001207vg.lst  001207vg
# 2    E:/nextcloud/ISicily/petrography/XRD/001207vg.lst  001207vg
# 3    E:/nextcloud/ISicily/petrography/XRD/001207vg.lst  001207vg
# 4    E:/nextcloud/ISicily/petrography/XRD/001207vg.lst  001207vg
# ..                                                 ...       ...       ...
# 201  C:/Users/Alessia/OneDrive - Nexus365/oxford/in...    004365
# 202  C:/Users/Alessia/OneDrive - Nexus365/oxford/in...    004365
# 203  C:/Users/Alessia/OneDrive - Nexus365/oxford/in...    004365
# 204  C:/Users/Alessia/OneDrive - Nexus365/oxford/in...    004365
# 205  C:/Users/Alessia/OneDrive - Nexus365/oxford/in...    004365
#
#     Parameter, Goal     Value       ESD
# 0          QCalcite   0.00441  0.00085,
# 1           Qquartz   0.40860   0.0033,
# 2        Qmicroint2   0.09400   0.0025,
# ...

# %%
xrd_converter.df_mineral_types
# Out:
#               subtype                      colname      category
# 0                   *           XRD other minerals
# 1             QALBINT       XRD albite content (%)   Plagioclase
# 2             Qalbint       XRD albite content (%)
# 3             QAlbite       XRD albite content (%)   Plagioclase
# 4           QAnalbite       XRD albite content (%)   Plagioclase
# ..                ...                          ...           ...
# 82          QSanina75  XRD Na-sanidine content (%)
# 83          QSANINA85  XRD Na-sanidine content (%)
# 84         QSiO2p3121       XRD quartz content (%)
# 85         QSiO2p3221       XRD quartz content (%)
# 86  Qsmectitedi2wfix1     XRD smectite content (%)  Clay Mineral
#
# [87 rows x 3 columns]

# %%
xrd_converter.df_params
# Out:
#                                        colname      category
# subtype
# *                           XRD other minerals
# qalbint                 XRD albite content (%)   Plagioclase
# qalbite                 XRD albite content (%)   Plagioclase
# qanalbite               XRD albite content (%)   Plagioclase
# qandesine_1           XRD andesine content (%)   Plagioclase
# ...                                        ...           ...
# qsanina75          XRD Na-sanidine content (%)
# qsanina85          XRD Na-sanidine content (%)
# qsio2p3121              XRD quartz content (%)
# qsio2p3221              XRD quartz content (%)
# qsmectitedi2wfix1     XRD smectite content (%)  Clay Mineral
#
# [82 rows x 2 columns]

# %%
xrd_converter.df_preproc
# Out:
# ESD (94.0) is larger than value (1.0) for ISic003373vg on qcalcite
# ESD (1.3) is larger than value (0.0) for ISic003373vg on qquartz
# ESD (96.0) is larger than value (0.0) for ISic003373vg on qchloritfxbg
# ESD (0.0028) is larger than value (0.0016) for tao31 on qmusc2m1
# ESD (0.00062) is larger than value (0.00025) for taoPiedi on qsio2p3121
# ESD (0.76) is larger than value (0.54) for ISic001138pvg on qcalcite
# ESD (0.024) is larger than value (0.017) for ISic001138pvg on qmusc2m1
# ESD (0.91) is larger than value (0.36) for ISic001138pvg on qkaolinitedis
# ESD (0.006) is larger than value (0.0042) for ISic001138pvg on qhematite
# ESD (0.06) is larger than value (0.042) for ISic001138pvg on qchlorite2b
# ESD (0.017) is larger than value (0.012) for ISic001138pvg on qquartz
# ESD (0.024) is larger than value (0.017) for ISic001138pvg on qalbite
# ESD (0.0048) is larger than value (0.0034) for ISic001138pvg on qenstatitemg06fe04ca
# ...

# %%
xrd_converter.df_output
# Out:
# ESD (94.0) is larger than value (1.0) for ISic003373vg on qcalcite
# ESD (1.3) is larger than value (0.0) for ISic003373vg on qquartz
# ESD (96.0) is larger than value (0.0) for ISic003373vg on qchloritfxbg
# ESD (0.0028) is larger than value (0.0016) for tao31 on qmusc2m1
# ESD (0.00062) is larger than value (0.00025) for taoPiedi on qsio2p3121
# ESD (0.76) is larger than value (0.54) for ISic001138pvg on qcalcite
# ESD (0.024) is larger than value (0.017) for ISic001138pvg on qmusc2m1
# ESD (0.91) is larger than value (0.36) for ISic001138pvg on qkaolinitedis
# ESD (0.006) is larger than value (0.0042) for ISic001138pvg on qhematite
# ESD (0.06) is larger than value (0.042) for ISic001138pvg on qchlorite2b
# ESD (0.017) is larger than value (0.012) for ISic001138pvg on qquartz
# ESD (0.024) is larger than value (0.017) for ISic001138pvg on qalbite
# ESD (0.0048) is larger than value (0.0034) for ISic001138pvg on qenstatitemg06fe04ca
# ...

# %%
xrd_converter.df_mineral_types
# Out:
#               subtype                      colname      category
# 0                   *           XRD other minerals
# 1             QALBINT       XRD albite content (%)   Plagioclase
# 2             Qalbint       XRD albite content (%)
# 3             QAlbite       XRD albite content (%)   Plagioclase
# 4           QAnalbite       XRD albite content (%)   Plagioclase
# ..                ...                          ...           ...
# 82          QSanina75  XRD Na-sanidine content (%)
# 83          QSANINA85  XRD Na-sanidine content (%)
# 84         QSiO2p3121       XRD quartz content (%)
# 85         QSiO2p3221       XRD quartz content (%)
# 86  Qsmectitedi2wfix1     XRD smectite content (%)  Clay Mineral
#
# [87 rows x 3 columns]

# %%
xrd_converter.df_output.loc['ISic000097']
# Out:
# ESD (94.0) is larger than value (1.0) for ISic003373vg on qcalcite
# ESD (1.3) is larger than value (0.0) for ISic003373vg on qquartz
# ESD (96.0) is larger than value (0.0) for ISic003373vg on qchloritfxbg
# ESD (0.0028) is larger than value (0.0016) for tao31 on qmusc2m1
# ESD (0.00062) is larger than value (0.00025) for taoPiedi on qsio2p3121
# ESD (0.76) is larger than value (0.54) for ISic001138pvg on qcalcite
# ESD (0.024) is larger than value (0.017) for ISic001138pvg on qmusc2m1
# ESD (0.91) is larger than value (0.36) for ISic001138pvg on qkaolinitedis
# ESD (0.006) is larger than value (0.0042) for ISic001138pvg on qhematite
# ESD (0.06) is larger than value (0.042) for ISic001138pvg on qchlorite2b
# ESD (0.017) is larger than value (0.012) for ISic001138pvg on qquartz
# ESD (0.024) is larger than value (0.017) for ISic001138pvg on qalbite
# ESD (0.0048) is larger than value (0.0034) for ISic001138pvg on qenstatitemg06fe04ca
# ...

# %%
xrd_converter.run()
# Out:
# Postprocessing XRD data @ 2024-08-26 18:21:17,126
# Saved: xrd_data_postprocessed.xlsx @ 2024-08-26 18:21:17,200
