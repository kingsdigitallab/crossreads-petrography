# %%
import sys; sys.path.append('..')
from crossreads_petrography.xrd import *

# %%
xrd_converter = XRDConverter()
# Out:
# Initializing XRDConverter: /Users/ryan/github/crossreads-petrography/data/input/XRD / /content/drive/MyDrive/Crossreads B D1/XRD input data @ 2024-07-17 09:49:55,710
# Authenticating and accessing Google Spreadsheet @ 2024-07-17 09:49:55,711

# %%
xrd_converter.df_xrd
# Out:
# Reading XRD data @ 2024-07-17 09:49:57,402
# Reading XRD data from /Users/ryan/github/crossreads-petrography/data/input/XRD @ 2024-07-17 09:49:57,402
# Reading dataframe from file: /Users/ryan/github/crossreads-petrography/data/input/XRD/xrd-results-tao.CSV @ 2024-07-17 09:49:57,403
# Reading dataframe from file: /Users/ryan/github/crossreads-petrography/data/input/XRD/XRD-results-sample.CSV @ 2024-07-17 09:49:57,409
# Read 426 rows from input data @ 2024-07-17 09:49:57,415
#                XRD calcite content (%)  XRD calcite content (%) ESD  \
# Sample
# ISic000004                      94.720                        0.490
# ISic000034                      85.400                        1.000
# ISic000036                      77.400                        1.200
# ISic000068                       0.000                        0.000
# ISic000069                      94.830                        0.330
# ISic000097p                      3.030                        0.350
# ...

# %%
xrd_converter.df_meta
# Out:
# Reading CrossReads sheet from Google Spreadsheet @ 2024-07-17 09:49:57,442
# Reading data from spreadsheet worksheet 0 @ 2024-07-17 09:49:57,443
# Read 177 rows from spreadsheet @ 2024-07-17 09:49:58,752
# 0                            entity type rock type rock desc1  \
# reference or rock id
# Capedri et al 2004             reference    marble    carrara
# Antonelli and Nestola 2021     reference    marble    carrara
# Antonelli and Nestola 2021     reference    marble    göktepe
# Antonelli and Lazzarini 2015   reference    marble    carrara
# Antonelli and Lazzarini 2015   reference    marble    paros-1
# ...                                  ...       ...        ...
# taoLastraR
# taoPiedi
# taoSarcofago
# taomascherome
# taoreclinato
#
# 0                                                       rock desc2  \
# reference or rock id
# Capedri et al 2004
# Antonelli and Nestola 2021
# Antonelli and Nestola 2021
# Antonelli and Lazzarini 2015  fantiscritti, ravaccione, fossacava
# ...

# %%
xrd_converter.df_updated
# Out:
# Updating CrossReads sheet with XRD data @ 2024-07-17 09:49:58,768
# Updated 0 values in 0 samples @ 2024-07-17 09:49:58,785

# %%
xrd_converter.save()
# Out:
# No updates to apply @ 2024-07-17 09:49:58,790

# %%
xrd_converter.run()
# Out:
# No updates to apply @ 2024-07-17 09:49:58,795
