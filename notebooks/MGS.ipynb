# %% [markdown]
# # MGS intersections

# %%
import sys; sys.path.append('..')
from crossreads_petrography import *
# Out:
# Loading config from /Users/ryan/github/crossreads-petrography/notebooks/../data/default_config.yaml

# %%
mgs = MgsConverter()
mgs
# Out:
# MgsConverter(
#     path = "/Users/ryan/github/crossreads-petrography/data/MGS",
#     path_input = "/Users/ryan/github/crossreads-petrography/data/MGS/input",
#     path_output = "/Users/ryan/github/crossreads-petrography/data/MGS/output",
# )

# %% [markdown]
# ### Isotope intersections

# %%
mgs.df_input.value_type.value_counts()
# Out:
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# value_type
# min wh     13
# min box    13
# median     13
# max box    13
# max wh     13
# Name: count, dtype: int64

# %%
mgs.df_output
# Out:
# Processing MGS intersections
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Determining polygon intersections
# Reading isotope curve data from: /Users/ryan/github/crossreads-petrography/data/Isotopes/input
# Loaded 208 rows of isotope curve data
# Reshaped data into 4160 points
# Loading crossreads spreadsheet for isotope points
# [nan, nan, 'Carrara', {'min': 0.278968983890681, 'max': 1.37338929314312}]
# [nan, nan, 'Göktepe', {'min': 0.343347323285781, 'max': 1.60944129418111}]
# [nan, nan, 'Docimium', {'min': 0.278968983890681, 'max': 2.0815444776525}]
# [nan, nan, 'Pentelikon', {'min': 0.278968983890681, 'max': 1.78111577442859}]
# [nan, nan, 'Hymettus', {'min': 0.343347323285781, 'max': 1.20171645010482}]
# [nan, nan, 'Paros-1', {'min': 0.772531886695302, 'max': 3.00429112526205}]
# [nan, nan, 'Proconnesos-1', {'min': 0.646694646571561, 'max': 4.48497819646674}]
# ...

# %%
mgs.run()
# Out:
# Running MGS intersections
# Saving MGS intersections
# Processing MGS intersections
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Determining polygon intersections
# Reading isotope curve data from: /Users/ryan/github/crossreads-petrography/data/Isotopes/input
# Loaded 208 rows of isotope curve data
# Reshaped data into 4160 points
# Loading crossreads spreadsheet for isotope points
# Loaded 166 rows from crossreads spreadsheet
# Processed 85 valid isotope points
# Determining polygon intersections
# Created 20 polygons for marble types
# Found 82 samples intersecting with polygons
# Found intersections for 83 samples
# Processed MGS intersections for 97 samples
# Saved MGS intersections to /Users/ryan/github/crossreads-petrography/data/MGS/output/mgs_intersections.xlsx
# MGS intersections processing completed

# %%
mgs.df_input
# Out:
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Error reading file /Users/ryan/github/crossreads-petrography/data/MGS/input/~$MGS-references-sheets.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mgs.df_input
#
# File ~/github/crossreads-petrography/notebooks/../crossreads_petrography/mgs.py:9, in MgsConverter.df_input(self)
#       6 @property
#       7 def df_input(self):
#       8     logger.info(f"Loading MGS data from: {self.path_input}")
# ----> 9     df = read_path(self.path_input)
#      10     logger.info(f"Loaded {len(df)} rows of MGS data")
#      11     return df
#
# File ~/github/crossreads-petrography/notebooks/../crossreads_petrography/utils.py:154, in read_path(path, worksheet_index, as_list, sep)
# ...
