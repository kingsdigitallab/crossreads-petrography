# %% [markdown]
# # MGS intersections

# %%
import sys; sys.path.append('..')
from crossreads_petrography import *
# Out:
# Loading config from /Users/ryan/github/crossreads-petrography/notebooks/../data/default_config.yaml

# %%
IsotopeConverter().path_output
# Out:
# '/Users/ryan/github/crossreads-petrography/data/Isotopes/output'

# %%
mgs = MgsConverter()
mgs
# Out:
# MgsConverter(
#     path = "/Users/ryan/github/crossreads-petrography/data/MGS",
#     path_input = "/Users/ryan/github/crossreads-petrography/data/MGS/input",
#     path_output = "/Users/ryan/github/crossreads-petrography/data/MGS/output",
# )

# %%
print(f"Docimium range: {mgs.df_ranges.loc['Docimium', 'wh_min']} - {mgs.df_ranges.loc['Docimium', 'wh_max']}")
print(f"Docimium box range: {mgs.df_ranges.loc['Docimium', 'box_min']} - {mgs.df_ranges.loc['Docimium', 'box_max']}")
print(f"Paros-1 range: {mgs.df_ranges.loc['Paros-1', 'wh_min']} - {mgs.df_ranges.loc['Paros-1', 'wh_max']}")
print(f"Paros-1 box range: {mgs.df_ranges.loc['Paros-1', 'box_min']} - {mgs.df_ranges.loc['Paros-1', 'box_max']}")
# Out:
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Calculating MGS ranges from input data
# ...

# %%
print(type(mgs.df_microscopy.loc['ISic000097', mgs.col_optical]))
print(type(mgs.df_microscopy.loc['ISic000097', mgs.col_digital]))
print(type(mgs.df_ranges.loc['Docimium', 'wh_min']))
# Out:
# Creating microscopy DataFrame from Metamorphic metadata
# Reading metadata from /Users/ryan/github/crossreads-petrography/data/Metadata/Metamorphic.xlsx
# Read 166 rows from metadata
# 33 samples with microscopy data
# Creating microscopy DataFrame from Metamorphic metadata
# Reading metadata from /Users/ryan/github/crossreads-petrography/data/Metadata/Metamorphic.xlsx
# Read 166 rows from metadata
# 33 samples with microscopy data
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>

# %%
optical_value = mgs.df_microscopy.loc['ISic000097', mgs.col_optical]
digital_value = mgs.df_microscopy.loc['ISic000097', mgs.col_digital]
print(f"Optical value: {optical_value}")
print(f"Digital value: {digital_value}")
# Out:
# Creating microscopy DataFrame from Metamorphic metadata
# Reading metadata from /Users/ryan/github/crossreads-petrography/data/Metadata/Metamorphic.xlsx
# Read 166 rows from metadata
# 33 samples with microscopy data
# Creating microscopy DataFrame from Metamorphic metadata
# Reading metadata from /Users/ryan/github/crossreads-petrography/data/Metadata/Metamorphic.xlsx
# Read 166 rows from metadata
# 33 samples with microscopy data
# Optical value: 1.4
# Digital value: 2.0

# %%
mgs.df_input
# Out:
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
#     value_mm value_type   subtype
# 0   0.278969     min wh   Carrara
# 1   0.493561    min box   Carrara
# 2   0.708154     median   Carrara
# 3   1.008583    max box   Carrara
# 4   1.373389     max wh   Carrara
# ..       ...        ...       ...
# 60  0.858369     min wh  Thasos-3
# 61  1.566523    min box  Thasos-3
# 62  1.802573     median  Thasos-3
# 63  2.875534    max box  Thasos-3
# 64  3.197423     max wh  Thasos-3
#
# [65 rows x 3 columns]

# %%
mgs.df_ranges
# Out:
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
#                  wh_min     wh_max   box_min   box_max
# subtype
# Aphrodisias    0.257510   4.484978  1.373389  2.789699
# Carrara        0.278969   1.373389  0.493561  1.008583
# Docimium       0.278969   2.081544  0.493561  1.587981
# Göktepe        0.343347   1.609441  0.493561  0.965665
# Hymettus       0.343347   1.201716  0.450643  0.772532
# Naxos          1.995708  12.000000  4.163090  7.575107
# Paros-1        0.772532   3.004291  1.008583  2.188841
# Paros-2 (3)    0.686695   4.570815  1.330471  3.068669
# Paros-4        1.008583   3.004291  1.373389  2.575107
# Pentelikon     0.278969   1.781116  0.686695  1.266093
# Proconnesos-1  0.646695   4.484978  1.652360  3.197423
# Thasos-1 (2)   1.786800   5.756773  2.537880  4.281400
# Thasos-3       0.858369   3.197423  1.566523  2.875534

# %%
mgs.df_microscopy
# Out:
# Creating microscopy DataFrame from Metamorphic metadata
# Reading metadata from /Users/ryan/github/crossreads-petrography/data/Metadata/Metamorphic.xlsx
# Read 166 rows from metadata
# 33 samples with microscopy data
#              optical microscopy MGS (mm)  digital microscopy MGS (mm)
# ISic
# ISic000097                          1.40                         2.00
# ISic000104                          0.80                         0.60
# ISic000107                           NaN                         1.60
# ISic000121                          0.80                         2.20
# ISic000132                           NaN                         1.50
# ISic000139                           NaN                         2.00
# ISic000139                           NaN                         2.10
# ISic000148                          0.50                         0.60
# ISic000151                           NaN                         0.35
# ...

# %%
mgs.df_output
# Out:
# Processing MGS intersections
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Creating microscopy DataFrame from Metamorphic metadata
# Reading metadata from /Users/ryan/github/crossreads-petrography/data/Metadata/Metamorphic.xlsx
# Read 166 rows from metadata
# 33 samples with microscopy data
# Processed MGS intersections for 33 samples
# Checking ISic000097 with optical value: 1.4
#   Comparing with Docimium:
#     Whisker: 0.278968983890681 <= 1.4 <= 2.0815444776525
#     Box: 0.49356126559544 <= 1.4 <= 1.58798075624329
#     Intersection: 🔬🔬
#     Current cell value: 🔬🔬
# Checking ISic000097 with optical value: 1.4
#   Comparing with Paros-1:
#     Whisker: 0.772531886695302 <= 1.4 <= 3.00429112526205
#     Box: 1.0085830691287 <= 1.4 <= 2.18884061850488
#     Intersection: 🔬🔬
#     Current cell value: 🔬🔬
# Checking ISic000097 with digital value: 2.0
# ...

# %%
print(mgs.df_output.loc['ISic000097', ['Docimium', 'Paros-1']])
# Out:
# Processing MGS intersections
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Creating microscopy DataFrame from Metamorphic metadata
# Reading metadata from /Users/ryan/github/crossreads-petrography/data/Metadata/Metamorphic.xlsx
# Read 166 rows from metadata
# 33 samples with microscopy data
# Checking ISic000097 with optical value: 1.4
#   Comparing with Docimium:
#     Whisker: 0.278968983890681 <= 1.4 <= 2.0815444776525
#     Box: 0.49356126559544 <= 1.4 <= 1.58798075624329
#     Intersection: 🔬🔬
#     Current cell value: 🔬🔬
# Checking ISic000097 with optical value: 1.4
#   Comparing with Paros-1:
#     Whisker: 0.772531886695302 <= 1.4 <= 3.00429112526205
#     Box: 1.0085830691287 <= 1.4 <= 2.18884061850488
#     Intersection: 🔬🔬
#     Current cell value: 🔬🔬
# Checking ISic000097 with digital value: 2.0
#   Comparing with Docimium:
# ...

# %%
print(mgs.df_output.index)
print(mgs.df_output.columns)
# Out:
# Processing MGS intersections
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Creating microscopy DataFrame from Metamorphic metadata
# Reading metadata from /Users/ryan/github/crossreads-petrography/data/Metadata/Metamorphic.xlsx
# Read 166 rows from metadata
# 33 samples with microscopy data
# Checking ISic000097 with optical value: 1.4
#   Comparing with Docimium:
#     Whisker: 0.278968983890681 <= 1.4 <= 2.0815444776525
#     Box: 0.49356126559544 <= 1.4 <= 1.58798075624329
#     Intersection: 🔬🔬
#     Current cell value: 🔬🔬
# Checking ISic000097 with optical value: 1.4
#   Comparing with Paros-1:
#     Whisker: 0.772531886695302 <= 1.4 <= 3.00429112526205
#     Box: 1.0085830691287 <= 1.4 <= 2.18884061850488
#     Intersection: 🔬🔬
#     Current cell value: 🔬🔬
# Checking ISic000097 with digital value: 2.0
#   Comparing with Docimium:
# ...

# %%
# Add this at the end of the df_output property method
print(f"Final DataFrame for ISic000097:")
print(mgs.df_output.loc['ISic000097'])
# Out:
# Processing MGS intersections
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Creating microscopy DataFrame from Metamorphic metadata
# Reading metadata from /Users/ryan/github/crossreads-petrography/data/Metadata/Metamorphic.xlsx
# Final DataFrame for ISic000097:
# Read 166 rows from metadata
# 33 samples with microscopy data
# Processed MGS intersections for 33 samples
# Checking ISic000097 with optical value: 1.4
#   Comparing with Docimium:
#     Whisker: 0.278968983890681 <= 1.4 <= 2.0815444776525
#     Box: 0.49356126559544 <= 1.4 <= 1.58798075624329
#     Intersection: 🔬🔬
#     Current cell value: 🔬🔬
# Checking ISic000097 with optical value: 1.4
#   Comparing with Paros-1:
#     Whisker: 0.772531886695302 <= 1.4 <= 3.00429112526205
#     Box: 1.0085830691287 <= 1.4 <= 2.18884061850488
#     Intersection: 🔬🔬
#     Current cell value: 🔬🔬
# ...

# %%
print(mgs.df_output.loc['ISic000097', 'Docimium'])
print(mgs.df_output.loc['ISic000097', 'Paros-1'])
# Out:
# Processing MGS intersections
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Creating microscopy DataFrame from Metamorphic metadata
# Reading metadata from /Users/ryan/github/crossreads-petrography/data/Metadata/Metamorphic.xlsx
# Read 166 rows from metadata
# 33 samples with microscopy data
# Processed MGS intersections for 33 samples
# Checking ISic000097 with optical value: 1.4
#   Comparing with Docimium:
#     Whisker: 0.278968983890681 <= 1.4 <= 2.0815444776525
#     Box: 0.49356126559544 <= 1.4 <= 1.58798075624329
#     Intersection: 🔬🔬
#     Current cell value: 🔬🔬
# Checking ISic000097 with optical value: 1.4
#   Comparing with Paros-1:
#     Whisker: 0.772531886695302 <= 1.4 <= 3.00429112526205
#     Box: 1.0085830691287 <= 1.4 <= 2.18884061850488
#     Intersection: 🔬🔬
#     Current cell value: 🔬🔬
# Checking ISic000097 with digital value: 2.0
# ...

# %%
mgs.run()
# Out:
# Running MGS intersections
# Saving MGS intersections
# Processing MGS intersections
# Calculating MGS ranges from input data
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Creating microscopy DataFrame from Metamorphic metadata
# Reading metadata from /Users/ryan/github/crossreads-petrography/data/Metadata/Metamorphic.xlsx
# Read 166 rows from metadata
# 33 samples with microscopy data
# Processed MGS intersections for 33 samples
# Saved MGS intersections to /Users/ryan/github/crossreads-petrography/data/MGS/output/2024-08-30/mgs_intersections.xlsx
# MGS intersections processing completed
# Checking ISic000097 with optical value: 1.4
#   Comparing with Docimium:
#     Whisker: 0.278968983890681 <= 1.4 <= 2.0815444776525
#     Box: 0.49356126559544 <= 1.4 <= 1.58798075624329
#     Intersection: 🔬🔬
#     Current cell value: 🔬🔬
# Checking ISic000097 with optical value: 1.4
#   Comparing with Paros-1:
# ...
