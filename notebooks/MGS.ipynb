# %% [markdown]
# # MGS intersections

# %%
import sys; sys.path.append('..')
from crossreads_petrography import *
# Out:
# Loading config from /Users/ryan/github/crossreads-petrography/notebooks/../data/default_config.yaml

# %%
mgs = MgsConverter()
mgs
# Out:
# MgsConverter(
#     path = "/Users/ryan/github/crossreads-petrography/data/MGS",
#     path_input = "/Users/ryan/github/crossreads-petrography/data/MGS/input",
#     path_output = "/Users/ryan/github/crossreads-petrography/data/MGS/output",
# )

# %%
mgs.df_input.value_type.value_counts()
# Out:
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# value_type
# min wh     13
# min box    13
# median     13
# max box    13
# max wh     13
# Name: count, dtype: int64

# %%
mgs.df_output
# Out:
# Processing MGS intersections
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Determining polygon intersections
# Reading isotope curve data from: /Users/ryan/github/crossreads-petrography/data/Isotopes/input
# Loaded 208 rows of isotope curve data
# Reshaped data into 4160 points
# Loading crossreads spreadsheet for isotope points
# Loaded 166 rows from crossreads spreadsheet
# Processed 85 valid isotope points
# Determining polygon intersections
# Created 20 polygons for marble types
# Found 82 samples intersecting with polygons
# Found intersections for 83 samples
# Processed MGS intersections for 97 samples
#                Aphrodisias CapDeGardeScritto Carrara Docimium EphesosBigio  \
# ISic
# ISic000097            🔬🔬🔍🔍                                🔬🔬🔍
# ISic000104              🔬🔍                      🔬🔬🔍🔍     🔬🔬🔍🔍
# ISic000121             🔬🔍🔍                        🔬🔬       🔬🔬
# ...

# %%
mgs.run()
# Out:
# Running MGS intersections
# Saving MGS intersections
# Processing MGS intersections
# Loading MGS data from: /Users/ryan/github/crossreads-petrography/data/MGS/input
# Loaded 65 rows of MGS data
# Determining polygon intersections
# Reading isotope curve data from: /Users/ryan/github/crossreads-petrography/data/Isotopes/input
# Loaded 208 rows of isotope curve data
# Reshaped data into 4160 points
# Loading crossreads spreadsheet for isotope points
# Loaded 166 rows from crossreads spreadsheet
# Processed 85 valid isotope points
# Determining polygon intersections
# Created 20 polygons for marble types
# Found 82 samples intersecting with polygons
# Found intersections for 83 samples
# Processed MGS intersections for 97 samples
# Saved MGS intersections to /Users/ryan/github/crossreads-petrography/data/MGS/output/mgs_intersections.xlsx
# MGS intersections processing completed
